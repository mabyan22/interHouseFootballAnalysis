# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

# %%
df = pd.read_csv('playerStatistics.csv')
df
# Out:
#           Player Name  Goals  Assists  Shots  Shots on Target  \
# 0          Sarim Raza      0        0      4                1
# 1          Momin Alam      0        0      3                2
# 2         Haris Undre      0        0      0                0
# 3      Hamdan ul Aziz      0        0      0                0
# 4        Hamza Minhaj      0        0      0                0
# 5          Aneequddin      1        0      2                1
# 6       Daniyal Waqas      0        0      1                0
# 7        Karim Kamran      0        0      3                1
# 8               Aabir      0        1      3                1
# 9      Asad Saad (GK)      0        0      0                0
# 10   Shahmeer Bukhari      0        0      1                0
# 11               Hadi      0        0      0                0
# 12      Subhan Mansha      0        0      3                1
# 13        Yuza Hashmi      0        0      0                0
# ...

# %%
#creating parameters and ranges for radar
params=list(df.columns)
params=params[10:]
ranges=[]
player_values=dict()

for i in params:
    a=min(df[params][i])
    a=a-(a*0.25)
    b=max(df[params][i])
    b=b+(b*0.25)
    ranges.append((a,b))
    
for i in range(len(df['Player Name'])):
    player_values[i]=df.iloc[i].values.tolist() 
    player_values[i]=player_values[i][10:]

# %%
for i in range(len(df['Player Name'])):
    radar = Radar()
    fig,ax=radar.plot_radar(
        ranges=ranges,params=params,values=player_values[i],
        radar_color=['indigo','violet'],alphas=[.25,.2],title={'title_name':df['Player Name'][i]}
    )
